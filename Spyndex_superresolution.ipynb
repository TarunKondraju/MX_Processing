# %%
import spyndex
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import rasterio
from PIL import Image
from rasterio import plot
from rasterio.plot import show

fp = r'D:\Tarun\iari\IARI_Sentinel_2122_season\Feb_2018\180222_field_masked_superresolution.tif'
img = rasterio.open(fp)
A = img.read(1)
B = img.read(2)
G = img.read(3)
R = img.read(4)
RE1 = img.read(5)
RE2 = img.read(6)
RE3 = img.read(7)
N = img.read(8)
N1 = img.read(9)
N2 = img.read(10)
S1 = img.read(12)
S2 = img.read(13)
NDVI = (N - R)/(N + R)
show(NDVI)
# type(NDVI)
img = Image.fromarray(NDVI, mode="F")
type(img)
show(img)
# img.save('D:\\Tarun\\iari\\Indices\\Validation\\011022_gee_CHI_image\\180222_superresolution_NDVI.tif','TIFF')
# Out:
# C:\Users\BDL\AppData\Local\Temp\ipykernel_19716\3374200904.py:24: RuntimeWarning: invalid value encountered in divide
#   NDVI = (N - R)/(N + R)
# C:\ProgramData\Anaconda3\envs\ee\lib\site-packages\matplotlib\image.py:468: RuntimeWarning: overflow encountered in subtract
#   A_scaled -= a_min
# C:\ProgramData\Anaconda3\envs\ee\lib\site-packages\matplotlib\image.py:468: RuntimeWarning: invalid value encountered in subtract
#   A_scaled -= a_min
# C:\ProgramData\Anaconda3\envs\ee\lib\site-packages\matplotlib\image.py:488: RuntimeWarning: overflow encountered in multiply
#   A_resampled *= ((a_max - a_min) / 0.8)
# C:\ProgramData\Anaconda3\envs\ee\lib\site-packages\matplotlib\colors.py:1026: RuntimeWarning: overflow encountered in float_scalars
#   resdat /= (vmax - vmin)
# C:\ProgramData\Anaconda3\envs\ee\lib\site-packages\matplotlib\colors.py:1026: RuntimeWarning: invalid value encountered in divide
#   resdat /= (vmax - vmin)
